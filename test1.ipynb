# %%
import django 
import os 
import sys
AUTH_USER_MODEL_SWAPPED=True
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"]='true'
project_name='core'
sys.path.append(os.getcwd())
os.environ.setdefault("DJANGO_SETTINGS_MODULE",f"{project_name}.settings")
django.setup()
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'env (Python 3.12.5)' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from django.db import connection
connection.vendor
# Out:
# 'postgresql'

# %%
from products.models import LaptopProduct , Cpu,  Gpu , Ram , UserAdmin , Brand

# %%
## TOKEN

# %%
import requests

headers = {
    'Authorization': 'Token 95b942de8de6c14a94e8f8963d0550df36cb6c2c',
    'Content-Type': 'application/json'
}

page=2
response = requests.get(f'http://127.0.0.1:8000/laptops/?page={page}', headers=headers)
response.json()
# Out:
# {'detail': 'Authentication credentials were not provided.'}

# %% [markdown]
# # jwt Token

# %% [markdown]
# #### acess

# %%
import requests

username="ahimsa"
password="ahimsa"

acess_url_params=f"http://127.0.0.1:8000/api/token/"
headers={
    'Content-Type': 'application/json'
}

obtain_data = {
"username": username,
"password": password
}

acess_response=requests.post(url=acess_url_params,headers=headers,json=obtain_data)
# obtain_response.json()

if acess_response.ok:
    refresh_response=acess_response.json()['refresh'] 
    acess_response=acess_response.json()['access']
    print(
        refresh_response,'\n',
        acess_response
    ) 
else:
    print(acess_response.json())
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoicmVmcmVzaCIsImV4cCI6MTcyNTgxNTU2NiwiaWF0IjoxNzI1NTU2MzY2LCJqdGkiOiI4Zjk4YTBjYThlOWY0M2I4OTc0ODJhYTc2NjY1ZDNhZCIsInVzZXJfaWQiOjF9.L9SkAfEpJ8JhCJXj_qBn00AWC_yOecGkt9qNmuYfhEQ
#  eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzI1NTU5OTY2LCJpYXQiOjE3MjU1NTYzNjYsImp0aSI6IjUzOWJiYWNmNjA4NTQ4ZTFhNjE5M2JhNzhjN2VlN2UwIiwidXNlcl9pZCI6MX0.h8itlAb4tNUjhNMjw2rpwgtRy5IYmau1zGVcOc8JOCc

# %% [markdown]
# #### RESFRESH

# %%
refresh_url_params=f"http://127.0.0.1:8000/api/token/refresh/"
headers={
    'Content-Type': 'application/json'
}

refresh_data= {
    'refresh':refresh_response
}

refresh_token_response=requests.post(url=refresh_url_params,headers=headers,json=refresh_data)
refresh_token_response.json() 

if refresh_token_response.ok:
    permanent_token= refresh_token_response.json()['access']
    print(permanent_token)
else:
    print(permanent_token)
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzI1NTU5OTY5LCJpYXQiOjE3MjU1NTYzNjYsImp0aSI6ImJlYzBhZjhjZGU0ZDQ2Mzk5MjBjNDIzMWViOTBjMzc1IiwidXNlcl9pZCI6MX0.Ktf2oRh9fxRADD_TM2p0cwkpgbQ5TJDdgqscH9LfQwE

# %% [markdown]
# ### use refresh permanent

# %%
permanent_token
# Out:
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ0b2tlbl90eXBlIjoiYWNjZXNzIiwiZXhwIjoxNzI1NTU5OTY5LCJpYXQiOjE3MjU1NTYzNjYsImp0aSI6ImJlYzBhZjhjZGU0ZDQ2Mzk5MjBjNDIzMWViOTBjMzc1IiwidXNlcl9pZCI6MX0.Ktf2oRh9fxRADD_TM2p0cwkpgbQ5TJDdgqscH9LfQwE'

# %%
headers = {
    'Authorization': f"Bearer {permanent_token}",
    'Content-Type': 'application/json'
}

page=4
response = requests.get(f'http://127.0.0.1:8000/laptops/?page={page}', headers=headers)
response.json()
# Out:
# {'detail': 'Invalid page.'}

# %%
# is the first access token usefull at all ?

# %%
UserAdmin.objects.filter()[0].id
# Out:
# 1

# %%
user1=UserAdmin.objects.filter()[0]
user1
# Out:
# <User: ahimsa>

# %%
cpu2=Cpu.objects.create(
    cpu_brand='INTEL',
    cpu_series='Core',
    cpu_model='i7-13420H',
    cpu_generation=13,
    cpu_sku='13420H',
    total_cores=6,
    performance_cores=4,
    efficiency_cores=2,
    threads=12,
    base_clock_speed=3.00,
    boost_clock_speed=4.60,
    l1_cache=0.48,
    l2_cache=2.00,
    l3_cache=8.00,
    tdp=45,
    max_operating_temperature=100.00,
    has_integrated_graphics=True,
    integrated_graphics_model='Intel UHD Graphics',
    integrated_graphics_max_frequency=1.45,
    lithography=10,
    release_date='2023-02-01',
    supports_hyperthreading=True,
    supports_virtualization=True,
    supports_overclocking=False
)

cpu1= Cpu.objects.create(
    cpu_brand='AMD',
    cpu_series='Ryzen',
    cpu_model='Ryzen 9 5800X',
    cpu_generation=5,
    cpu_sku='5800X',
    total_cores=8,
    performance_cores=None,
    efficiency_cores=None,
    threads=16,
    base_clock_speed=3.80,
    boost_clock_speed=4.70,
    l1_cache=0.512,
    l2_cache=4.00,
    l3_cache=32.00,
    tdp=105,
    max_operating_temperature=95.00,
    has_integrated_graphics=False,
    integrated_graphics_model=None,
    integrated_graphics_max_frequency=None,
    lithography=7,
    release_date='2020-11-05',
    supports_hyperthreading=True,
    supports_virtualization=True,
    supports_overclocking=True,
    
)



# Creating multiple CPU instances
cpu3 = Cpu.objects.create(
    cpu_brand='INTEL',
    cpu_series='Core',
    cpu_model='i5-13420H',
    cpu_generation=13,
    cpu_sku='13420H',
    total_cores=6,
    performance_cores=4,
    efficiency_cores=2,
    threads=12,
    base_clock_speed=3.00,
    boost_clock_speed=4.60,
    l1_cache=0.48,
    l2_cache=2.00,
    l3_cache=8.00,
    tdp=45,
    max_operating_temperature=100.00,
    has_integrated_graphics=True,
    integrated_graphics_model='Intel UHD Graphics',
    integrated_graphics_max_frequency=1.45,
    lithography=10,
    release_date='2023-02-01',
    supports_hyperthreading=True,
    supports_virtualization=True,
    supports_overclocking=False
)

cpu4 = Cpu.objects.create(
    cpu_brand='AMD',
    cpu_series='Ryzen',
    cpu_model='Ryzen 7 5800X',
    cpu_generation=5,
    cpu_sku='5800X',
    total_cores=8,
    performance_cores=None,
    efficiency_cores=None,
    threads=16,
    base_clock_speed=3.80,
    boost_clock_speed=4.70,
    l1_cache=0.512,
    l2_cache=4.00,
    l3_cache=32.00,
    tdp=105,
    max_operating_temperature=95.00,
    has_integrated_graphics=False,
    integrated_graphics_model=None,
    integrated_graphics_max_frequency=None,
    lithography=7,
    release_date='2020-11-05',
    supports_hyperthreading=True,
    supports_virtualization=True,
    supports_overclocking=True
)

cpu5 = Cpu.objects.create(
    cpu_brand='APPLE',
    cpu_series='M1',
    cpu_model='M1 Pro',
    cpu_generation=1,
    cpu_sku='M1P',
    total_cores=10,
    performance_cores=8,
    efficiency_cores=2,
    threads=16,
    base_clock_speed=3.20,
    boost_clock_speed=None,  # Not applicable for Apple's M1
    l1_cache=1.00,
    l2_cache=6.00,
    l3_cache=32.00,
    tdp=70,
    max_operating_temperature=85.00,
    has_integrated_graphics=True,
    integrated_graphics_model='Apple GPU',
    integrated_graphics_max_frequency=1.80,
    lithography=5,
    release_date='2021-10-25',
    supports_hyperthreading=False,
    supports_virtualization=True,
    supports_overclocking=False
)

# %%
cpu1.cpu_brand
# Out:
# 'AMD'

# %%
ram1=Ram.objects.create(
    ram_brand='Corsair',
    ram_type='DDR4',
    ram_size=16,
    ram_speed=3200,
    cas_latency=16,
    voltage=1.35,
    form_factor='DIMM',
    release_date='2022-01-01'
)

ram2=Ram.objects.create(
    ram_brand='G.Skill',
    ram_type='DDR5',
    ram_size=32,
    ram_speed=3600,
    cas_latency=18,
    voltage=1.2,
    form_factor='SO-DIMM',
    release_date='2023-03-15'
)



ram3 = Ram.objects.create(
    ram_brand='Corsair',
    ram_type='DDR5',
    ram_size=16,
    ram_speed=3200,
    cas_latency=16,
    voltage=1.35,
    form_factor='DIMM',
    release_date='2022-01-01'
)

ram4 = Ram.objects.create(
    ram_brand='G.Skill',
    ram_type='DDR5',
    ram_size=32,
    ram_speed=3600,
    cas_latency=18,
    voltage=1.2,
    form_factor='SO-DIMM',
    release_date='2023-03-15'
)

ram5 = Ram.objects.create(
    ram_brand='Kingston',
    ram_type='DDR6',
    ram_size=8,
    ram_speed=2666,
    cas_latency=15,
    voltage=1.35,
    form_factor='DIMM',
    release_date='2021-06-10'
)

# %%
gpu1=Gpu.objects.create(
    gpu_brand='Nvidia',
    gpu_series='RTX',
    gpu_model='RTX 3050',
    memory_size=8,
    memory_type='GDDR5',
    memory_clock_speed=1750,
    core_clock_speed=1500,
    boost_clock_speed=1777,
    cuda_cores=2560,
    stream_processors=None,
    tdp=130,
    interface='PCIe 4.0',
    release_date='2021-07-01'
)

gpu2=Gpu.objects.create(
    gpu_brand='AMD',
    gpu_series='Radeon',
    gpu_model='Radeon RX 6800',
    memory_size=12,
    memory_type='GDDR5',
    memory_clock_speed=2000,
    core_clock_speed=1605,
    boost_clock_speed=1845,
    cuda_cores=None,
    stream_processors=3840,
    tdp=250,
    interface='PCIe 4.0',
    release_date='2020-11-18'
)



# Creating multiple GPU instances
gpu3 = Gpu.objects.create(
    gpu_brand='Nvidia',
    gpu_series='RTX',
    gpu_model='RTX 3050',
    memory_size=8,
    memory_type='GDDR6',
    memory_clock_speed=1750,
    core_clock_speed=1500,
    boost_clock_speed=1777,
    cuda_cores=2560,
    stream_processors=None,
    tdp=130,
    interface='PCIe 4.0',
    release_date='2021-07-01'
)

gpu4 = Gpu.objects.create(
    gpu_brand='AMD',
    gpu_series='Radeon',
    gpu_model='Radeon RX 6800',
    memory_size=12,
    memory_type='GDDR6',
    memory_clock_speed=2000,
    core_clock_speed=1605,
    boost_clock_speed=1845,
    cuda_cores=None,
    stream_processors=3840,
    tdp=250,
    interface='PCIe 4.0',
    release_date='2020-11-18'
)

gpu5 = Gpu.objects.create(
    gpu_brand='Nvidia',
    gpu_series='RTX',
    gpu_model='RTX 3080',
    memory_size=10,
    memory_type='GDDR6X',
    memory_clock_speed=1900,
    core_clock_speed=1440,
    boost_clock_speed=1710,
    cuda_cores=8704,
    stream_processors=None,
    tdp=320,
    interface='PCIe 4.0',
    release_date='2020-09-17'
)

# %%
LaptopProduct.objects.create(
    brand='Dell',
    model='XPS 15',
    series='XPS',
    price=1500.00,
    images=None,
    usage='general',
    description='High-performance laptop suitable for a variety of tasks.',
    user_maker=user1,
    cpu=cpu1,
    ram=ram1,
    gpu=gpu1,
)
# Out:
# <LaptopProduct: Dell - XPS - XPS 15>

# %%
from itertools import product , permutations

# %%
user2=UserAdmin.objects.create_user(
    username='admin' ,
    email='mamadadmin@gmail.com' , 
    password= 'admin123',
)

user2=UserAdmin.objects.create_user(
    username='mamad2' ,
    email='mamad2@gmail.com' , 
    password= '1232',
)

# %%
brands_data = [
    {'brand_name': 'Dell', 'country': 'USA'},
    {'brand_name': 'HP', 'country': 'USA'},
    {'brand_name': 'Lenovo', 'country': 'China'},
    {'brand_name': 'Apple', 'country': 'USA'},
    {'brand_name': 'Asus', 'country': 'Taiwan'},
    {'brand_name': 'Acer', 'country': 'Taiwan'},
    {'brand_name': 'MSI', 'country': 'Taiwan'},
    # Add more brands as needed
]

for brand_data in brands_data:
    Brand.objects.create(**brand_data)

# %%
cpus = Cpu.objects.all()
gpus = Gpu.objects.all()
rams = Ram.objects.all()
brand=Brand.objects.all()

all_combination=list(product(cpus, gpus, rams,brand))
all_combination
# Out:
# [(<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i7-13420H>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (1)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (2)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (3)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (4)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (5)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (6)>),
#  (<Cpu: AMD - Ryzen - Ryzen 9 5800X>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: INTEL - Core - i5-13420H>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
# ...
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (1)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (2)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (3)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (4)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (7)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (1)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (2)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (3)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (4)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3050 - 8>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (7)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (1)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (2)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (3)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (4)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: AMD - Radeon RX 6800 - 12>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (7)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR4 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (1)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (2)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (3)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (4)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Corsair - DDR5 - 16>,
#   <Brand: Brand object (7)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (1)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (2)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (3)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (4)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: G.Skill - DDR5 - 32>,
#   <Brand: Brand object (7)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (1)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (2)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (3)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (4)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (5)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (6)>),
#  (<Cpu: APPLE - M1 - M1 Pro>,
#   <Gpu: Nvidia - RTX 3080 - 10>,
#   <Ram: Kingston - DDR6 - 8>,
#   <Brand: Brand object (7)>)]

# %%
import random

random.randint(10000000,120000000)
# Out:
# 19342437

# %%
random.choice(brand_series.values())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 random.choice(brand_series.values())
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\random.py:348, in Random.choice(self, seq)
#     346 if not len(seq):
#     347     raise IndexError('Cannot choose from an empty sequence')
# --> 348 return seq[self._randbelow(len(seq))]
#
# TypeError: 'dict_values' object is not subscriptable

# %%
brand_series={ 
'lenovo':['Loq','Legion','Y'],
'asus':['G','GL','Rog'],
'dell':['stedio','inspiron','vostro'],
'msi':['Summit','pro','modern'],
}

# for brand in Brand.objects.all():
#     if brand.brand_name.lower() in brand_series:
#         print(random.choice(brand_series.values()) )

# %%
LaptopProduct.objects.all()
# Out:
# <QuerySet []>

# %%
# Out:
# (3502, {'products.LaptopProduct': 3502})

# %%
# Fetch all Cpu, Gpu, and Ram instances from the database
cpus = Cpu.objects.all()
gpus = Gpu.objects.all()
rams = Ram.objects.all()
users=UserAdmin.objects.all()
brands=Brand.objects.all()
# Generate all combinations of Cpu, Gpu, and Ram
all_combinations = list(product(cpus, gpus, rams,users,brands))

# Create LaptopProduct instances for each combination
for cpu, gpu, ram , user,brand in all_combinations:
    brand_name=brand.brand_name.lower()
    series_list=brand_series.get(brand_name,[])
    series_selected=random.choice(series_list) if series_list  else 'Unknown'

    LaptopProduct.objects.create(
        brand=brand, 
        model=f"{cpu.cpu_brand} {cpu.cpu_model} - {gpu.gpu_model} - {ram.ram_size}GB",  # Placeholder model
        series=series_selected, 
        cpu=cpu,
        gpu=gpu,
        ram=ram,
        price=random.randint(10000000,120000000),  
        images=None,
        usage=random.choice(['iot','general','gaming','graphic','enginiering','ai','general_programing']),
        description=f"Laptop with {cpu.cpu_brand} {cpu.cpu_model}, {gpu.gpu_model}, {ram.ram_size}GB RAM.{brand.brand_name}",
        user_maker=user  # Assuming there is at least one user
    )

# %%
LaptopProduct.objects.filter(brand__brand_name='Lenovo')

# LaptopProduct.objects.all().delete()
# Out:
# <QuerySet [<LaptopProduct: Brand object (3) - Loq - INTEL i7-13420H - RTX 3050 - 16GB>, <LaptopProduct: Brand object (3) - Legion - INTEL i7-13420H - RTX 3050 - 16GB>, <LaptopProduct: Brand object (3) - Y - INTEL i7-13420H - RTX 3050 - 16GB>, <LaptopProduct: Brand object (3) - Legion - INTEL i7-13420H - RTX 3050 - 16GB>, <LaptopProduct: Brand object (3) - Y - INTEL i7-13420H - RTX 3050 - 32GB>, <LaptopProduct: Brand object (3) - Y - INTEL i7-13420H - RTX 3050 - 32GB>, <LaptopProduct: Brand object (3) - Legion - INTEL i7-13420H - RTX 3050 - 32GB>, <LaptopProduct: Brand object (3) - Y - INTEL i7-13420H - RTX 3050 - 32GB>, <LaptopProduct: Brand object (3) - Y - INTEL i7-13420H - RTX 3050 - 16GB>, <LaptopProduct: Brand object (3) - Y - INTEL i7-13420H - RTX 3050 - 16GB>, <LaptopProduct: Brand object (3) - Y - INTEL i7-13420H - RTX 3050 - 16GB>, <LaptopProduct: Brand object (3) - Loq - INTEL i7-13420H - RTX 3050 - 16GB>, <LaptopProduct: Brand object (3) - Y - INTEL i7-13420H - RTX 3050 - 32GB>, <LaptopProduct: Brand object (3) - Legion - INTEL i7-13420H - RTX 3050 - 32GB>, <LaptopProduct: Brand object (3) - Legion - INTEL i7-13420H - RTX 3050 - 32GB>, <LaptopProduct: Brand object (3) - Legion - INTEL i7-13420H - RTX 3050 - 32GB>, <LaptopProduct: Brand object (3) - Legion - INTEL i7-13420H - RTX 3050 - 8GB>, <LaptopProduct: Brand object (3) - Loq - INTEL i7-13420H - RTX 3050 - 8GB>, <LaptopProduct: Brand object (3) - Legion - INTEL i7-13420H - RTX 3050 - 8GB>, <LaptopProduct: Brand object (3) - Loq - INTEL i7-13420H - RTX 3050 - 8GB>, '...(remaining elements truncated)...']>

# %%
exclude_fields=['id','update_time','images','description','create_time']
query_fields = [field.name for field in LaptopProduct._meta.get_fields() if field.name not in exclude_fields]
query_fields
# Out:
# ['brand', 'model', 'series', 'cpu', 'ram', 'price', 'usage']

# %%
from django.db.models import Q , F  , Avg , Sum, Min,Max,Count

filters= Q()
filters
# Out:
# <Q: (AND: )>

# %%
import requests
the_response=requests.get('http://127.0.0.1:8000/laptops/')
test_request=the_response.json()
test_request
# Out:
# {'detail': 'Authentication credentials were not provided.'}

# %%
filtered_laptops = [laptop for laptop in test_request if laptop.get('brand') == 'asus']
filtered_laptops
# Out:
# []

# %%
# value = test_request.query_params.get('brand')

for laptop in test_request:
    # print(laptop)
    for field in query_fields:
        value=laptop.get(field)
        if value:
            filters &= Q(**{field: value}) #{'brand': 'lenovo'}   #(AND: ('brand', 'lenovo')) (AND: ('model', 'y700'))

LaptopProduct.objects.filter(filters)
# Out:
# <QuerySet []>

# %%
LaptopProduct.objects.get()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 LaptopProduct.objects.get('brand')
#
# File e:\projects\laptop_project_django\venv\Lib\site-packages\django\db\models\manager.py:87, in BaseManager._get_queryset_methods.<locals>.create_method.<locals>.manager_method(self, *args, **kwargs)
#      85 @wraps(method)
#      86 def manager_method(self, *args, **kwargs):
# ---> 87     return getattr(self.get_queryset(), name)(*args, **kwargs)
#
# File e:\projects\laptop_project_django\venv\Lib\site-packages\django\db\models\query.py:623, in QuerySet.get(self, *args, **kwargs)
#     618 if self.query.combinator and (args or kwargs):
#     619     raise NotSupportedError(
#     620         "Calling QuerySet.get(...) with filters after %s() is not "
#     621         "supported." % self.query.combinator
#     622     )
# --> 623 clone = self._chain() if self.query.combinator else self.filter(*args, **kwargs)
#     624 if self.query.can_filter() and not self.query.distinct_fields:
#     625     clone = clone.order_by()
#
# File e:\projects\laptop_project_django\venv\Lib\site-packages\django\db\models\query.py:1436, in QuerySet.filter(self, *args, **kwargs)
#    1431 """
#    1432 Return a new QuerySet instance with the args ANDed to the existing
#    1433 set.
#    1434 """
#    1435 self._not_support_combined_queries("filter")
# -> 1436 return self._filter_or_exclude(False, args, kwargs)
#
# File e:\projects\laptop_project_django\venv\Lib\site-packages\django\db\models\query.py:1454, in QuerySet._filter_or_exclude(self, negate, args, kwargs)
#    1452     clone._deferred_filter = negate, args, kwargs
#    1453 else:
# -> 1454     clone._filter_or_exclude_inplace(negate, args, kwargs)
#    1455 return clone
#
# File e:\projects\laptop_project_django\venv\Lib\site-packages\django\db\models\query.py:1461, in QuerySet._filter_or_exclude_inplace(self, negate, args, kwargs)
#    1459     self._query.add_q(~Q(*args, **kwargs))
#    1460 else:
# -> 1461     self._query.add_q(Q(*args, **kwargs))
#
# File e:\projects\laptop_project_django\venv\Lib\site-packages\django\db\models\sql\query.py:1546, in Query.add_q(self, q_object)
#    1537 # For join promotion this case is doing an AND for the added q_object
#    1538 # and existing conditions. So, any existing inner join forces the join
#    1539 # type to remain inner. Existing outer joins can however be demoted.
#    1540 # (Consider case where rel_a is LOUTER and rel_a__col=1 is added - if
#    1541 # rel_a doesn't produce any rows, then the whole condition must fail.
#    1542 # So, demotion is OK.
#    1543 existing_inner = {
#    1544     a for a in self.alias_map if self.alias_map[a].join_type == INNER
#    1545 }
# -> 1546 clause, _ = self._add_q(q_object, self.used_aliases)
#    1547 if clause:
#    1548     self.where.add(clause, AND)
#
# File e:\projects\laptop_project_django\venv\Lib\site-packages\django\db\models\sql\query.py:1577, in Query._add_q(self, q_object, used_aliases, branch_negated, current_negated, allow_joins, split_subq, check_filterable, summarize)
#    1573 joinpromoter = JoinPromoter(
#    1574     q_object.connector, len(q_object.children), current_negated
#    1575 )
#    1576 for child in q_object.children:
# -> 1577     child_clause, needed_inner = self.build_filter(
#    1578         child,
#    1579         can_reuse=used_aliases,
#    1580         branch_negated=branch_negated,
#    1581         current_negated=current_negated,
#    1582         allow_joins=allow_joins,
#    1583         split_subq=split_subq,
#    1584         check_filterable=check_filterable,
#    1585         summarize=summarize,
#    1586     )
#    1587     joinpromoter.add_votes(needed_inner)
#    1588     if child_clause:
#
# File e:\projects\laptop_project_django\venv\Lib\site-packages\django\db\models\sql\query.py:1424, in Query.build_filter(self, filter_expr, branch_negated, current_negated, can_reuse, allow_joins, split_subq, reuse_with_filtered_relation, check_filterable, summarize)
#    1422         condition = self.build_lookup(["exact"], condition, True)
#    1423     return WhereNode([condition], connector=AND), []
# -> 1424 arg, value = filter_expr
#    1425 if not arg:
#    1426     raise FieldError("Cannot parse keyword query %r" % arg)
#
# ValueError: too many values to unpack (expected 2)

# %%
from rest_framework.response import  Response
from rest_framework.decorators import api_view
from rest_framework.request import Request
from products.models import LaptopProduct
from products.api.v1.serializers import LaptopProductSerializers
from rest_framework import status

# %%
for field in query_fields:
    # If the field is present in the query parameters, add it to the filter
    # value = request.query_params.get(field)
    value=
